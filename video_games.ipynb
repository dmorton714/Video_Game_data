# %%
import pandas as pd 
import plotly as pt 
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# def crit_cal(row):
#     if row['Critic_Score'] >=90:
#         return row['Name']

# %%
# df["Crit>90"] = df.apply(crit_cal, axis=1)
# df

# %%
# makes a data frame with critic score over 90 
critic_90 = df.query('Critic_Score >= 90')
critic_90 = critic_90.sort_values(by = 'Critic_Score', ascending=False)
# critic_90

# %%
# shows the platfor with critic scores above 90 
critic_90['Platform'].value_counts()
# Out:
# PC      60
# PS2     55
# PS3     43
# X360    41
# XB      28
# PS      26
# GC      23
# Wii     12
# GBA     10
# PS4      8
# XOne     7
# DS       5
# DC       4
# 3DS      4
# WiiU     3
# PSV      2
# PSP      2
# Name: Platform, dtype: int64

# %%
# critic_90['Platform'].value_counts().plot.bar()

# %%
# shows publishers above 90

# %%
# user scores above 90
user_90 = df.query('User_Score >= 9')
user_90 = user_90.sort_values(by = 'User_Score', ascending=False)
user_90
# Out:
#                                            Name Platform  Year_of_Release  \
# 14414                        Breath of Fire III      PSP           2005.0
# 3417      Harvest Moon: Friends of Mineral Town      GBA           2003.0
# 8976            Boktai: The Sun is in Your Hand      GBA           2003.0
# 16631                             Karnaaj Rally      GBA           2003.0
# 16550               Wade Hixton's Counter Punch      GBA           2004.0
# ...                                         ...      ...              ...
# 1786           Dance Dance Revolution Extreme 2      PS2           2005.0
# 6079                                 Links 2004       XB           2003.0
# 1841   Tom Clancy's Splinter Cell: Chaos Theory       XB           2005.0
# 6110                    ATV Quad Power Racing 2       GC           2003.0
# 17                Grand Theft Auto: San Andreas      PS2           2004.0
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
# shows the platfor with user scores above 90 
user_90['Platform'].value_counts()
# Out:
# PS2     91
# GBA     42
# XB      41
# GC      36
# PS      24
# PC      23
# DS      17
# PSP      7
# DC       5
# Wii      4
# PSV      3
# 3DS      3
# PS3      2
# WiiU     2
# X360     2
# XOne     1
# PS4      1
# Name: Platform, dtype: int64

# %%
# user_90['Platform'].value_counts().plot.bar()

# %%
x1 = critic_90['Platform'].value_counts()
x2 = user_90['Platform'].value_counts()

comp = {
  "Critic": x1,
  "User": x2,
}
comp = pd.DataFrame(data=comp)

# comp.plot.bar()

# %%
frames = critic_90['Name'], user_90['Name']
agree = pd.concat(frames)
agree.value_counts()
# Out:
# The Witcher 3: Wild Hunt                  6
# Grand Theft Auto V                        5
# Rayman Legends                            5
# Tony Hawk's Pro Skater 3                  5
# The Legend of Zelda: Twilight Princess    4
#                                          ..
# Colin McRae Rally 2.0                     1
# Shin Megami Tensei: Persona 4             1
# Bayonetta                                 1
# MLB 09: The Show                          1
# ATV Quad Power Racing 2                   1
# Name: Name, Length: 468, dtype: int64

# %%
# crit_user_90 = df.query('User_Score >= 9' and 'Critic_Score >= 90')
 
crit_user_90 = df.loc[(df['Critic_Score'] >= 90) & (df['User_Score'] >= 9)]
crit_user_90.head()
# Out:
#                               Name Platform  Year_of_Release         Genre  \
# 17   Grand Theft Auto: San Andreas      PS2           2004.0        Action
# 65               Final Fantasy VII       PS           1997.0  Role-Playing
# 67                  Gran Turismo 2       PS           1999.0        Racing
# 97            Super Mario Galaxy 2      Wii           2010.0      Platform
# 106                       Tekken 3       PS           1998.0      Fighting
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17          Take-Two Interactive      9.43      0.40      0.41        10.57
# 65   Sony Computer Entertainment      3.01      2.47      3.28         0.96
# 67   Sony Computer Entertainment      3.88      3.42      1.69         0.50
# 97                      Nintendo      3.56      2.35      0.98         0.62
# 106  Sony Computer Entertainment      3.27      2.22      1.40         0.29
#
# ...

# %%
crit_user_90['Platform'].value_counts()
# Out:
# PS2     12
# PC      11
# PS       8
# GC       7
# GBA      5
# Wii      3
# XB       3
# PS3      2
# X360     1
# WiiU     1
# PS4      1
# 3DS      1
# XOne     1
# PSV      1
# DS       1
# DC       1
# Name: Platform, dtype: int64

# %%
x1 = critic_90['Platform'].value_counts()
x2 = user_90['Platform'].value_counts()
x3 = crit_user_90['Platform'].value_counts()

comp = {
  "Critic": x1,
  "User": x2,
  "agreed" : x3,
}
comp = pd.DataFrame(data=comp)

comp.plot.bar()
# Out:
# <Axes: >

# %%
# biggest publishers

# publish = df.groupby(['Publisher', 'Global_Sales'])
# publish.first()

# %%
# df2 = df.groupby(['publisher']).sum()
# df2 =df.groupby(['Courses']).sum()
# df2.first()

df2 = df.groupby(['Publisher'])['Global_Sales'].sum().reset_index()
df2 = df2.sort_values(by = 'Global_Sales', ascending=False)
df2.head(20)
# Out:
#                                   Publisher  Global_Sales
# 361                                Nintendo       1788.81
# 139                         Electronic Arts       1116.96
# 21                               Activision        731.16
# 458             Sony Computer Entertainment        606.48
# 529                                 Ubisoft        471.61
# 498                    Take-Two Interactive        403.82
# 492                                     THQ        338.44
# 277            Konami Digital Entertainment        282.39
# 448                                    Sega        270.35
# 349                      Namco Bandai Games        254.62
# 325                  Microsoft Game Studios        248.32
# 85                                   Capcom        200.02
# 53                                    Atari        156.83
# 553  Warner Bros. Interactive Entertainment        151.79
# 468                             Square Enix        144.35
# ...

# %%
df2.iloc[0:20].plot.bar()
# Out:
# <Axes: >
